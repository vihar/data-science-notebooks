# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv("ipl/matches.csv")

# %%
df.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df.drop(['umpire3'],axis=1,inplace=True)

# %%
ipl_df=df

# %%
ipl_df.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# dtype: object

# %%
# team_name = 'Mumbai Indians'
mi_df = df.loc[ (df['team1'] == "Mumbai Indians") | (df['team2'] == "Mumbai Indians")]

# %%
mi_df["player_of_match"].value_counts().head(20)
# Out:
# RG Sharma          12
# KA Pollard          9
# SR Tendulkar        8
# AT Rayudu           7
# Harbhajan Singh     6
# SL Malinga          5
# DR Smith            5
# A Nehra             4
# SK Raina            4
# KH Pandya           4
# MEK Hussey          3
# SPD Smith           3
# V Sehwag            3
# LMP Simmons         3
# CH Gayle            3
# KC Sangakkara       3
# JH Kallis           3
# SE Marsh            2
# MM Patel            2
# N Rana              2
# Name: player_of_match, dtype: int64

# %%
mi_df["result"].value_counts()
# Out:
# normal    156
# tie         1
# Name: result, dtype: int64

# %%
mi_df.head()
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
#
#                      team2             toss_winner toss_decision  result  \
# 1   Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 6           Mumbai Indians          Mumbai Indians         field  normal
# 9           Mumbai Indians          Mumbai Indians         field  normal
# 11          Mumbai Indians          Mumbai Indians         field  normal
# 15          Mumbai Indians          Mumbai Indians         field  normal
#
#     dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
win_runs = mi_df["win_by_runs"]>0
win_runs.value_counts()
# Out:
# False    80
# True     77
# Name: win_by_runs, dtype: int64

# %%
win_wk = mi_df["win_by_wickets"]>0
win_wk.value_counts()
# Out:
# True     79
# False    78
# Name: win_by_wickets, dtype: int64

# %%
mi_df['umpire1'].value_counts()
# Out:
# HDPK Dharmasena          27
# Asad Rauf                13
# AK Chaudhary             12
# BR Doctrove              12
# S Ravi                   11
# BF Bowden                10
# Nitin Menon               7
# Aleem Dar                 7
# M Erasmus                 7
# A Nand Kishore            5
# RE Koertzen               4
# NJ Llong                  3
# RK Illingworth            3
# S Das                     3
# SK Tarapore               3
# BG Jerling                2
# AY Dandekar               2
# DJ Harper                 2
# SS Hazare                 2
# JD Cloete                 2
# MR Benson                 2
# CB Gaffaney               2
# IL Howell                 2
# KN Ananthapadmanabhan     2
# VA Kulkarni               2
# S Asnani                  2
# K Srinath                 1
# SJ Davis                  1
# K Hariharan               1
# A Deshmukh                1
# AM Saheba                 1
# BNJ Oxenford              1
# C Shamshuddin             1
# ...

# %%
mi_df.head()
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 6    7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
#
#                      team2             toss_winner toss_decision  result  \
# 1   Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 6           Mumbai Indians          Mumbai Indians         field  normal
# 9           Mumbai Indians          Mumbai Indians         field  normal
# 11          Mumbai Indians          Mumbai Indians         field  normal
# 15          Mumbai Indians          Mumbai Indians         field  normal
#
#     dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
mi_df.describe()
win_cnt = mi_df.loc[mi_df['winner']=="Mumbai Indians"]

# %%
win_cnt.shape
# Out:
# (92, 17)

# %%
win_cnt.tail(30)
# Out:
#       id  season           city        date                        team1  \
# 433  434    2013         Mumbai  2013-05-07               Mumbai Indians
# 438  439    2013           Pune  2013-05-11                Pune Warriors
# 443  444    2013         Mumbai  2013-05-13          Sunrisers Hyderabad
# 446  447    2013         Mumbai  2013-05-15               Mumbai Indians
# 455  456    2013        Kolkata  2013-05-24             Rajasthan Royals
# 456  457    2013        Kolkata  2013-05-26               Mumbai Indians
# 478  479    2014         Mumbai  2014-05-03              Kings XI Punjab
# 483  484    2014         Mumbai  2014-05-06               Mumbai Indians
# 492  493    2014      Hyderabad  2014-05-12          Sunrisers Hyderabad
# 500  501    2014      Ahmedabad  2014-05-19               Mumbai Indians
# 504  505    2014     Chandigarh  2014-05-21              Kings XI Punjab
# 507  508    2014         Mumbai  2014-05-23               Mumbai Indians
# ...

# %%
win_cnt.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# dtype: object

# %%
ven_df = win_cnt.groupby("venue").winner.count()
ven_df.plot(kind="bar")

# %%
mitoss_win = mi_df.loc[mi_df["toss_winner"]=="Mumbai Indians"]

# %%
mitoss_win.winner.value_counts().plot(kind="bar")

# %%
mitoss_loss = mi_df.loc[mi_df["toss_winner"]!="Mumbai Indians"]

# %%
mitoss_loss.winner.value_counts().plot(kind="bar")

# %%
mi_loss = mi_df.loc[mi_df["winner"]!="Mumbai Indians"]

# %%
mi_lo
